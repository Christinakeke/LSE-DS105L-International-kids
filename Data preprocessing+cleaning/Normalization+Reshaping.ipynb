# %%
import pandas as pd

# Read in the original dataframe from the Excel file
monthly_average_CNY = pd.read_excel('monthly_average_CNY.xlsx')

# Find the minimum and maximum values of the monthly average CNY
min_CNY = min(monthly_average_CNY.iloc[:,-1])
max_CNY = max(monthly_average_CNY.iloc[:,-1])

# Define the Max-Min normalization function
def MaxMinNormalization(x):
    """[0,1] normalization"""
    x = (x - min_CNY) / (max_CNY - min_CNY)
    return x

# Create a new dataframe with the same columns as the original dataframe
normalized_dataframe_CNY = pd.DataFrame({
    'Date': monthly_average_CNY['index'],
    'Exchange Rate': None
})

# Fill in the normalized exchange rate values
for i in range(len(monthly_average_CNY)):
    normalized_dataframe_CNY.iloc[i,1] = MaxMinNormalization(monthly_average_CNY.iloc[i,1])

# Save the normalized dataframe to a new Excel file
normalized_dataframe_CNY.to_excel('normalized_dataframe_CNY.xlsx', index=False)

# %%
# Read in the original dataframe from the Excel file
monthly_average_GBP = pd.read_excel('monthly_average_GBP.xlsx')

# Find the minimum and maximum values of the monthly average CNY
min_GBP = min(monthly_average_GBP.iloc[:,-1])
max_GBP = max(monthly_average_GBP.iloc[:,-1])

# Define the Max-Min normalization function
def MaxMinNormalization(x):
    """[0,1] normalization"""
    x = (x - min_GBP) / (max_GBP - min_GBP)
    return x

# Create a new dataframe with the same columns as the original dataframe
normalized_dataframe_GBP = pd.DataFrame({
    'Date': monthly_average_GBP['index'],
    'Exchange Rate': None
})

# Fill in the normalized exchange rate values
for i in range(len(monthly_average_GBP)):
    normalized_dataframe_GBP.iloc[i,1] = MaxMinNormalization(monthly_average_GBP.iloc[i,1])

# %%
# Read in the original dataframe from the Excel file
monthly_average_RUB = pd.read_excel('monthly_average_RUB.xlsx')

# Find the minimum and maximum values of the monthly average CNY
min_RUB = min(monthly_average_RUB.iloc[:,-1])
max_RUB = max(monthly_average_RUB.iloc[:,-1])

# Define the Max-Min normalization function
def MaxMinNormalization(x):
    """[0,1] normalization"""
    x = (x - min_RUB) / (max_RUB - min_RUB)
    return x

# Create a new dataframe with the same columns as the original dataframe
normalized_dataframe_RUB = pd.DataFrame({
    'Date': monthly_average_RUB['index'],
    'Exchange Rate': None
})

# Fill in the normalized exchange rate values
for i in range(len(monthly_average_RUB)):
    normalized_dataframe_RUB.iloc[i,1] = MaxMinNormalization(monthly_average_RUB.iloc[i,1])

# %%
# Read in the original dataframe from the Excel file
monthly_average_JPY = pd.read_excel('monthly_average_JPY.xlsx')

# Find the minimum and maximum values of the monthly average CNY
min_JPY = min(monthly_average_JPY.iloc[:,-1])
max_JPY = max(monthly_average_JPY.iloc[:,-1])

# Define the Max-Min normalization function
def MaxMinNormalization(x):
    """[0,1] normalization"""
    x = (x - min_JPY) / (max_JPY - min_JPY)
    return x

# Create a new dataframe with the same columns as the original dataframe
normalized_dataframe_JPY = pd.DataFrame({
    'Date': monthly_average_JPY['index'],
    'Exchange Rate': None
})

# Fill in the normalized exchange rate values
for i in range(len(monthly_average_JPY)):
    normalized_dataframe_JPY.iloc[i,1] = MaxMinNormalization(monthly_average_JPY.iloc[i,1])

# %%
# Read in the original dataframe from the Excel file
monthly_average_EUR = pd.read_excel('monthly_average_EUR.xlsx')

# Find the minimum and maximum values of the monthly average CNY
min_EUR = min(monthly_average_EUR.iloc[:,-1])
max_EUR = max(monthly_average_EUR.iloc[:,-1])

# Define the Max-Min normalization function
def MaxMinNormalization(x):
    """[0,1] normalization"""
    x = (x - min_EUR) / (max_EUR - min_EUR)
    return x

# Create a new dataframe with the same columns as the original dataframe
normalized_dataframe_EUR = pd.DataFrame({
    'Date': monthly_average_EUR['index'],
    'Exchange Rate': None
})

# Fill in the normalized exchange rate values
for i in range(len(monthly_average_EUR)):
    normalized_dataframe_EUR.iloc[i,1] = MaxMinNormalization(monthly_average_EUR.iloc[i,1])

# %%
# Read in the original dataframe from the Excel file
monthly_average_KRW = pd.read_excel('monthly_average_KRW.xlsx')

# Find the minimum and maximum values of the monthly average CNY
min_KRW = min(monthly_average_KRW.iloc[:,-1])
max_KRW = max(monthly_average_KRW.iloc[:,-1])

# Define the Max-Min normalization function
def MaxMinNormalization(x):
    """[0,1] normalization"""
    x = (x - min_KRW) / (max_KRW - min_KRW)
    return x

# Create a new dataframe with the same columns as the original dataframe
normalized_dataframe_KRW = pd.DataFrame({
    'Date': monthly_average_KRW['index'],
    'Exchange Rate': None
})

# Fill in the normalized exchange rate values
for i in range(len(monthly_average_KRW)):
    normalized_dataframe_KRW.iloc[i,1] = MaxMinNormalization(monthly_average_KRW.iloc[i,1])

# %%
# Read in the original dataframe from the Excel file
monthly_average_CAD = pd.read_excel('monthly_average_CAD.xlsx')

# Find the minimum and maximum values of the monthly average CNY
min_CAD = min(monthly_average_CAD.iloc[:,-1])
max_CAD = max(monthly_average_CAD.iloc[:,-1])

# Define the Max-Min normalization function
def MaxMinNormalization(x):
    """[0,1] normalization"""
    x = (x - min_CAD) / (max_CAD - min_CAD)
    return x

# Create a new dataframe with the same columns as the original dataframe
normalized_dataframe_CAD = pd.DataFrame({
    'Date': monthly_average_CAD['index'],
    'Exchange Rate': None
})

# Fill in the normalized exchange rate values
for i in range(len(monthly_average_CAD)):
    normalized_dataframe_CAD.iloc[i,1] = MaxMinNormalization(monthly_average_CAD.iloc[i,1])

# %%
# Read in the original dataframe from the Excel file
monthly_average_INR = pd.read_excel('monthly_average_INR.xlsx')

# Find the minimum and maximum values of the monthly average CNY
min_INR = min(monthly_average_INR.iloc[:,-1])
max_INR = max(monthly_average_INR.iloc[:,-1])

# Define the Max-Min normalization function
def MaxMinNormalization(x):
    """[0,1] normalization"""
    x = (x - min_INR) / (max_INR - min_INR)
    return x

# Create a new dataframe with the same columns as the original dataframe
normalized_dataframe_INR = pd.DataFrame({
    'Date': monthly_average_INR['index'],
    'Exchange Rate': None
})

# Fill in the normalized exchange rate values
for i in range(len(monthly_average_INR)):
    normalized_dataframe_INR.iloc[i,1] = MaxMinNormalization(monthly_average_INR.iloc[i,1])

# %% [markdown]
# ## Conact Dataframe

# %%
df1=pd.read_excel('CPI_data.xlsx')
mask = df1['LOCATION'] == 'CHN'
CHN_data = df1.loc[mask]
CHN_data = CHN_data.reset_index(drop=True)
normalized_dataframe_CNY = normalized_dataframe_CNY.reset_index(drop=True)
df_CHN = pd.concat([CHN_data, normalized_dataframe_CNY], axis=1)
df_CHN
# Out:
#     LOCATION       TIME  Value       Date Exchange Rate
# 0        CHN 2013-01-01    2.0 2013-01-31      0.830262
# 1        CHN 2013-02-01    3.2 2013-02-28      0.819263
# 2        CHN 2013-03-01    2.1 2013-03-31      0.833852
# 3        CHN 2013-04-01    2.4 2013-04-30      0.865937
# 4        CHN 2013-05-01    2.1 2013-05-31      0.912807
# ..       ...        ...    ...        ...           ...
# 115      CHN 2022-08-01    2.5 2022-08-31      0.310467
# 116      CHN 2022-09-01    2.8 2022-09-30      0.141084
# 117      CHN 2022-10-01    2.1 2022-10-31           0.0
# 118      CHN 2022-11-01    1.6 2022-11-30       0.01816
# 119      CHN 2022-12-01    1.8 2022-12-31      0.167635
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'FRA'
FRA_data = df1.loc[mask]
FRA_data = FRA_data.reset_index(drop=True)
normalized_dataframe_EUR = normalized_dataframe_EUR.reset_index(drop=True)
df_FRA = pd.concat([FRA_data, normalized_dataframe_EUR], axis=1)
df_FRA
# Out:
#     LOCATION       TIME     Value       Date Exchange Rate
# 0        FRA 2013-01-01  1.169711 2013-01-31      0.869661
# 1        FRA 2013-02-01  1.042305 2013-02-28      0.881715
# 2        FRA 2013-03-01  0.972940 2013-03-31      0.783098
# 3        FRA 2013-04-01  0.688259 2013-04-30      0.800832
# 4        FRA 2013-05-01  0.800000 2013-05-31      0.787465
# ..       ...        ...       ...        ...           ...
# 115      FRA 2022-08-01  5.913125 2022-08-31      0.070904
# 116      FRA 2022-09-01  5.551915 2022-09-30      0.019856
# 117      FRA 2022-10-01  6.200466 2022-10-31           0.0
# 118      FRA 2022-11-01  6.150130 2022-11-30      0.098415
# 119      FRA 2022-12-01  5.850718 2022-12-31      0.191136
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'DEU'
DEU_data = df1.loc[mask]
DEU_data = DEU_data.reset_index(drop=True)
normalized_dataframe_EUR = normalized_dataframe_EUR.reset_index(drop=True)
df_DEU = pd.concat([DEU_data, normalized_dataframe_EUR], axis=1)
df_DEU
# Out:
#     LOCATION       TIME      Value       Date Exchange Rate
# 0        DEU 2013-01-01   1.653697 2013-01-31      0.869661
# 1        DEU 2013-02-01   1.545894 2013-02-28      0.881715
# 2        DEU 2013-03-01   1.440922 2013-03-31      0.783098
# 3        DEU 2013-04-01   1.154957 2013-04-30      0.800832
# 4        DEU 2013-05-01   1.539942 2013-05-31      0.787465
# ..       ...        ...        ...        ...           ...
# 115      DEU 2022-08-01   7.901907 2022-08-31      0.070904
# 116      DEU 2022-09-01   9.990917 2022-09-30      0.019856
# 117      DEU 2022-10-01  10.388440 2022-10-31           0.0
# 118      DEU 2022-11-01  10.045250 2022-11-30      0.098415
# 119      DEU 2022-12-01   8.550855 2022-12-31      0.191136
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'ITA'
ITA_data = df1.loc[mask]
ITA_data = ITA_data.reset_index(drop=True)
normalized_dataframe_EUR = normalized_dataframe_EUR.reset_index(drop=True)
df_ITA = pd.concat([ITA_data, normalized_dataframe_EUR], axis=1)
df_ITA
# Out:
#     LOCATION       TIME      Value       Date Exchange Rate
# 0        ITA 2013-01-01   2.203065 2013-01-31      0.869661
# 1        ITA 2013-02-01   1.908397 2013-02-28      0.881715
# 2        ITA 2013-03-01   1.614435 2013-03-31      0.783098
# 3        ITA 2013-04-01   1.134215 2013-04-30      0.800832
# 4        ITA 2013-05-01   1.134215 2013-05-31      0.787465
# ..       ...        ...        ...        ...           ...
# 115      ITA 2022-08-01   8.372978 2022-08-31      0.070904
# 116      ITA 2022-09-01   8.865586 2022-09-30      0.019856
# 117      ITA 2022-10-01  11.837120 2022-10-31           0.0
# 118      ITA 2022-11-01  11.770240 2022-11-30      0.098415
# 119      ITA 2022-12-01  11.632270 2022-12-31      0.191136
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'CAN'
CAN_data = df1.loc[mask]
CAN_data = CAN_data.reset_index(drop=True)
normalized_dataframe_CAD = normalized_dataframe_CAD.reset_index(drop=True)
df_CAN = pd.concat([CAN_data, normalized_dataframe_CAD], axis=1)
df_CAN
# Out:
#     LOCATION       TIME     Value       Date Exchange Rate
# 0        CAN 2013-01-01  0.497100 2013-01-31           1.0
# 1        CAN 2013-02-01  1.237624 2013-02-28      0.946379
# 2        CAN 2013-03-01  0.986031 2013-03-31      0.895907
# 3        CAN 2013-04-01  0.409165 2013-04-30      0.912826
# 4        CAN 2013-05-01  0.737101 2013-05-31      0.908337
# ..       ...        ...       ...        ...           ...
# 115      CAN 2022-08-01  7.012623 2022-08-31      0.226023
# 116      CAN 2022-09-01  6.857943 2022-09-30      0.152683
# 117      CAN 2022-10-01  6.879777 2022-10-31      0.080848
# 118      CAN 2022-11-01  6.796116 2022-11-30      0.136073
# 119      CAN 2022-12-01  6.319445 2022-12-31      0.098809
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'GBR'
GBR_data = df1.loc[mask]
GBR_data = GBR_data.reset_index(drop=True)
normalized_dataframe_GBP = normalized_dataframe_GBP.reset_index(drop=True)
df_GBR = pd.concat([GBR_data, normalized_dataframe_GBP], axis=1)
df_GBR
# Out:
#     LOCATION       TIME  Value       Date Exchange Rate
# 0        GBR 2013-01-01    2.4 2013-01-31      0.809465
# 1        GBR 2013-02-01    2.5 2013-02-28      0.726916
# 2        GBR 2013-03-01    2.5 2013-03-31      0.656448
# 3        GBR 2013-04-01    2.2 2013-04-30      0.696042
# 4        GBR 2013-05-01    2.4 2013-05-31      0.692594
# ..       ...        ...    ...        ...           ...
# 115      GBR 2022-08-01    8.6 2022-08-31      0.115228
# 116      GBR 2022-09-01    8.8 2022-09-30      0.005857
# 117      GBR 2022-10-01    9.6 2022-10-31           0.0
# 118      GBR 2022-11-01    9.3 2022-11-30      0.080783
# 119      GBR 2022-12-01    9.2 2022-12-31      0.151678
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'JPN'
JPN_data = df1.loc[mask]
JPN_data = JPN_data.reset_index(drop=True)
normalized_dataframe_JPY = normalized_dataframe_JPY.reset_index(drop=True)
df_JPN = pd.concat([JPN_data, normalized_dataframe_JPY], axis=1)
df_JPN
# Out:
#     LOCATION       TIME  Value       Date Exchange Rate
# 0        JPN 2013-01-01   -0.3 2013-01-31           1.0
# 1        JPN 2013-02-01   -0.7 2013-02-28      0.893813
# 2        JPN 2013-03-01   -0.9 2013-03-31      0.850105
# 3        JPN 2013-04-01   -0.7 2013-04-30      0.774528
# 4        JPN 2013-05-01   -0.3 2013-05-31      0.704061
# ..       ...        ...    ...        ...           ...
# 115      JPN 2022-08-01    3.0 2022-08-31       0.13172
# 116      JPN 2022-09-01    3.0 2022-09-30      0.043815
# 117      JPN 2022-10-01    3.7 2022-10-31           0.0
# 118      JPN 2022-11-01    3.8 2022-11-30      0.057209
# 119      JPN 2022-12-01    4.0 2022-12-31      0.140188
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'KOR'
KOR_data = df1.loc[mask]
KOR_data = KOR_data.reset_index(drop=True) 
normalized_dataframe_KRW = normalized_dataframe_KRW.reset_index(drop=True)
df_KOR = pd.concat([KOR_data, normalized_dataframe_KRW], axis=1)
df_KOR
# Out:
#     LOCATION       TIME     Value       Date Exchange Rate
# 0        KOR 2013-01-01  1.628636 2013-01-31      0.848452
# 1        KOR 2013-02-01  1.583177 2013-02-28      0.779714
# 2        KOR 2013-03-01  1.460475 2013-03-31      0.732951
# 3        KOR 2013-04-01  1.329622 2013-04-30      0.679934
# 4        KOR 2013-05-01  1.148536 2013-05-31        0.7078
# ..       ...        ...       ...        ...           ...
# 115      KOR 2022-08-01  5.712895 2022-08-31      0.201441
# 116      KOR 2022-09-01  5.583018 2022-09-30      0.061638
# 117      KOR 2022-10-01  5.670053 2022-10-31           0.0
# 118      KOR 2022-11-01  5.035140 2022-11-30      0.138539
# 119      KOR 2022-12-01  5.036524 2022-12-31      0.257716
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'IND'
IND_data = df1.loc[mask]
IND_data = IND_data.reset_index(drop=True)
normalized_dataframe_INR = normalized_dataframe_INR.reset_index(drop=True)
df_IND = pd.concat([IND_data, normalized_dataframe_INR], axis=1)
df_IND
# Out:
#     LOCATION       TIME      Value       Date Exchange Rate
# 0        IND 2013-01-01  11.616160 2013-01-31      0.978578
# 1        IND 2013-02-01  12.060300 2013-02-28           1.0
# 2        IND 2013-03-01  11.442790 2013-03-31      0.968921
# 3        IND 2013-04-01  10.243900 2013-04-30      0.972865
# 4        IND 2013-05-01  10.679610 2013-05-31      0.943353
# ..       ...        ...        ...        ...           ...
# 115      IND 2022-08-01   5.853659 2022-08-31      0.067514
# 116      IND 2022-09-01   6.488240 2022-09-30      0.052496
# 117      IND 2022-10-01   6.084868 2022-10-31      0.002592
# 118      IND 2022-11-01   5.409706 2022-11-30      0.020491
# 119      IND 2022-12-01   5.502392 2022-12-31           0.0
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'RUS'
RUS_data = df1.loc[mask]
RUS_data = RUS_data.reset_index(drop=True)
normalized_dataframe_RUB = normalized_dataframe_RUB.reset_index(drop=True)
df_RUS = pd.concat([RUS_data, normalized_dataframe_RUB], axis=1)
df_RUS
# Out:
#     LOCATION       TIME     Value       Date Exchange Rate
# 0        RUS 2013-01-01  7.074063 2013-01-31      0.998594
# 1        RUS 2013-02-01  7.276754 2013-02-28           1.0
# 2        RUS 2013-03-01  7.020775 2013-03-31      0.971814
# 3        RUS 2013-04-01  7.234155 2013-04-30      0.948624
# 4        RUS 2013-05-01  7.383506 2013-05-31      0.949864
# ..       ...        ...       ...        ...           ...
# 115      NaN        NaT       NaN 2022-08-31      0.303899
# 116      NaN        NaT       NaN 2022-09-30      0.309766
# 117      NaN        NaT       NaN 2022-10-31      0.294486
# 118      NaN        NaT       NaN 2022-11-30      0.302176
# 119      NaN        NaT       NaN 2022-12-31      0.249872
#
# [120 rows x 5 columns]

# %%
mask = df1['LOCATION'] == 'USA'
df_USA= df1.loc[mask]
df_USA
# Out:
#     LOCATION       TIME     Value
# 840      USA 2013-01-01  1.594865
# 841      USA 2013-02-01  1.977924
# 842      USA 2013-03-01  1.473896
# 843      USA 2013-04-01  1.063085
# 844      USA 2013-05-01  1.361965
# ..       ...        ...       ...
# 955      USA 2022-08-01  8.262692
# 956      USA 2022-09-01  8.201670
# 957      USA 2022-10-01  7.745427
# 958      USA 2022-11-01  7.110323
# 959      USA 2022-12-01  6.454401
#
# [120 rows x 3 columns]

# %% [markdown]
# ## Reshape dataframe according to year series

# %%
# Create an empty dictionary to store the new dataframes
yearly_dfs = {}

df_list = [df_CHN, df_USA, df_FRA, df_DEU, df_ITA, df_IND, df_RUS, df_GBR, df_CAN, df_KOR, df_JPN]

for df in df_list:
    df.loc[:, 'TIME'] = pd.to_datetime(df.loc[:, 'TIME'])

# Loop through each year from 2013 to 2022
for year in range(2013, 2023):
    # Create a list to store the dataframes for the current year
    dfs_for_year = []
    # Loop through each original dataframe
    for df_name in ['df_CHN', 'df_FRA', 'df_DEU', 'df_ITA', 'df_IND', 'df_RUS', 'df_GBR', 'df_CAN', 'df_KOR','df_JPN']:
        # Extract the year from the TIME column and select only the rows for the current year
        df_for_year = globals()[df_name][globals()[df_name]['TIME'].dt.year == year]
        # Append the dataframe to the list
        dfs_for_year.append(df_for_year)
    # Concatenate all the dataframes for the current year into a single dataframe
    yearly_dfs[str(year)] = pd.concat(dfs_for_year, ignore_index=True)

# Access the new dataframes using their year as a key
df_2013=yearly_dfs['2013']  # dataframe for 2013
df_2014=yearly_dfs['2014']
df_2015=yearly_dfs['2015']
df_2016=yearly_dfs['2016']
df_2017=yearly_dfs['2017']
df_2018=yearly_dfs['2018']
df_2019=yearly_dfs['2019']
df_2020=yearly_dfs['2020']
df_2021=yearly_dfs['2021']
df_2022=yearly_dfs['2022']
# Out:
# /var/folders/7t/q4xs_2kn20v_3868fkmt4bg00000gn/T/ipykernel_1319/3136979814.py:7: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'TIME'] = pd.to_datetime(df.loc[:, 'TIME'])
# /var/folders/7t/q4xs_2kn20v_3868fkmt4bg00000gn/T/ipykernel_1319/3136979814.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'TIME'] = pd.to_datetime(df.loc[:, 'TIME'])
# ...

# %%
merged_df = pd.concat(yearly_dfs.values())

# %%
df2=pd.read_excel('merged_df.xlsx')
p2 = ggplot(df2, aes(x='TIME', y='Exchange Rate', color='LOCATION')) + geom_line() + labs(title='Exchange rate', x='Time', y='Exchange rate') + scale_color_discrete(name='Country') + theme_classic() +  scale_x_datetime(date_labels='%Y')
p2
# Out:
# <ggplot: (8785146828843)>

# %%
final_2013= pd.merge(df_2013, df_USA, on='TIME', how='inner')
final_2013= final_2013.rename(columns={'Value_x': 'CPI', 'Value_y': 'USA_CPI'})
final_2013.to_excel('final_2013.xlsx', index=False)

# %%
from plotnine import *

# create plot
p = ggplot(df_2013, aes(x='TIME', y='Exchange Rate', color='LOCATION')) + geom_line() + labs(title='2013', x='Time', y='Exchange Rate') + scale_color_discrete(name='Country') + theme_classic()

p
# Out:
# <ggplot: (8779274993613)>

# %%
# create plot

from plotnine import *

p1 = ggplot(df1, aes(x='TIME', y='Value', color='LOCATION')) + geom_line() + labs(title='Inflation', x='Time', y='CPI') + scale_color_discrete(name='Country') + theme_classic() +  scale_x_datetime(date_labels='%Y')

p1
# Out:
# <ggplot: (8785116963792)>
